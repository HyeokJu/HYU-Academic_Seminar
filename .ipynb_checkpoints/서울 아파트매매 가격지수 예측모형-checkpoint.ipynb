# %% [markdown]
# # 1. 데이터 및 기본 작업

# %% [markdown]
# ## 1.1 라이브러리 불러오기

# %%
import warnings
warnings.filterwarnings(action='ignore')

import pandas as pd
import numpy as np
from datetime import datetime, timedelta

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

import torch
import torch.nn as nn
import torch.optim as optim
from pytorchtools import EarlyStopping

# %% [markdown]
# ## 1.2 폰트 및 함수 세팅

# %%
# 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
# 성능 측정 함수 
def score(actual, prediction):
    rmse = round(np.sqrt(mean_squared_error(actual, prediction)), 4)
    mae = round(mean_absolute_error(actual, prediction), 4)
    return rmse, mae

# %%
# 시계열 그래프 시각화 함수
def time_series_plot(time, data, title, ylab):
    
    # 그래프 크기 설정
    plt.figure(figsize=(12, 6))
    
    # 그래프 그리기
    plt.plot(time, data)
    
    # 축 이름, 글자 크기, 그리드 설정
    plt.title(title, fontsize=20)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    plt.xlabel('시간', fontsize=18)
    plt.ylabel(ylab, fontsize=18)
    plt.grid(True)
    plt.tight_layout()
    
    # 그래프 보이기
    plt.show()

# %%
# 산점도 시각화 함수
def variable_scatterplot(xlab, ylab):

    # 그림 크기 설정
    plt.figure(figsize=(8, 6))  
    
    # 산점도 그리기
    scatterplot = sns.scatterplot(x=xlab, y=ylab, data=data)

    # 축 레이블 설정
    scatterplot.set_xlabel(xlab, fontsize=18)
    scatterplot.set_ylabel(ylab, fontsize=18)
    plt.xticks(fontsize=16)  # x축 눈금 레이블의 글자 크기 설정
    plt.yticks(fontsize=16)  # y축 눈금 레이블의 글자 크기 설정
    plt.grid(True)
    
    plt.show()

# %%
# 결과 시각화 함수 (실제 값 vs 모델 예측 결과)
def result_plot(start, end, pivot, actual, prediction, model_name):
    time_range = pd.date_range(start=start, end=end, freq='M')
    
    # 그래프 크기 설정
    plt.figure(figsize=(12, 6))

    # 그래프 그리기
    plt.plot(time_range, actual, label='실제 값', color='black')
    plt.plot(time_range, prediction, label='예측 값', color='red')
    
    # 학습, 예축 구간 분기선
    plt.axvline(x = pd.to_datetime(pivot), color='gray', linestyle='--')
    
    # 축 제목, 크기 설정
    plt.xlabel('Time', fontsize=18)
    plt.ylabel('소비자물가지수', fontsize=18)
    plt.title(model_name + '모델', fontsize=20)
    plt.legend(fontsize=18)
    plt.grid(True)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    plt.tight_layout()
    
    # 그래프 보이기
    plt.show()

# %% [markdown]
# ## 1.3 데이터 불러오기

# %%
# 데이터 불러오기
data = pd.read_csv('data.csv')
data = data.drop(['ESI'], axis=1) # 경제심리지수(ESI)는 정의 상 다중공선성이 있으므로 제거
data.columns = ['아파트 매매 실거래가격지수', '아파트 전세가격지수', 'M1 유동성', '한국은행 기준금리', '경기선행지수'] # 열 이름 설정
data
# Out:
#      아파트 매매 실거래가격지수  아파트 전세가격지수   M1 유동성  한국은행 기준금리   경기선행지수
# 0           100.000     100.000  100.000       2.75  100.000
# 1           100.414     100.576  100.973       2.75  100.136
# 2           101.381     101.295  101.462       2.75  100.305
# 3           101.796     101.727  102.838       2.75  100.465
# 4           102.072     101.871  103.035       2.50  100.587
# ..              ...         ...      ...        ...      ...
# 120         197.928     127.770  260.584       3.50   99.417
# 121         201.934     123.453  259.061       3.50   99.362
# 122         204.834     121.007  257.754       3.50   99.395
# 123         208.149     120.144  257.047       3.50   99.490
# 124         211.050     120.000  255.125       3.50   99.620
#
# [125 rows x 5 columns]

# %% [markdown]
# # 2. 탐색적 데이터 분석

# %% [markdown]
# ## 2.1 변수의 시계열 그래프

# %%
months = pd.date_range(start='2013-01-01', periods=len(data), freq='M')
time_series_plot(months, data['아파트 매매 실거래가격지수'], '아파트 매매 실거래가격지수', '지수(2013.01=100)')

# %%
time_series_plot(months, data['경기선행지수'], '경기선행지수', '지수(2013.01=100)')

# %%
time_series_plot(months, data['한국은행 기준금리'], '한국은행 기준금리', '%')

# %%
time_series_plot(months, data['아파트 전세가격지수'], '아파트 전세가격지수', '지수(2013.01=100)')

# %%
time_series_plot(months, data['M1 유동성'], 'M1 유동성', '지수(2013.01=100)')

# %% [markdown]
# ## 2.2 변수 간 상관관계 확인

# %%
# 한 시점 미래의 아파트 매매 실거래가격지수를 종속변수로 설정
ASPI_1 = data['아파트 매매 실거래가격지수'][1:].tolist() + [np.nan] 
data['미래 아파트 매매 실거래가격지수'] = ASPI_1
data
# Out:
#      아파트 매매 실거래가격지수  아파트 전세가격지수   M1 유동성  한국은행 기준금리   경기선행지수  \
# 0           100.000     100.000  100.000       2.75  100.000
# 1           100.414     100.576  100.973       2.75  100.136
# 2           101.381     101.295  101.462       2.75  100.305
# 3           101.796     101.727  102.838       2.75  100.465
# 4           102.072     101.871  103.035       2.50  100.587
# ..              ...         ...      ...        ...      ...
# 120         197.928     127.770  260.584       3.50   99.417
# 121         201.934     123.453  259.061       3.50   99.362
# 122         204.834     121.007  257.754       3.50   99.395
# 123         208.149     120.144  257.047       3.50   99.490
# 124         211.050     120.000  255.125       3.50   99.620
#
#      미래 아파트 매매 실거래가격지수
# 0              100.414
# 1              101.381
# 2              101.796
# 3              102.072
# 4              101.519
# ..                 ...
# 120            201.934
# 121            204.834
# 122            208.149
# 123            211.050
# 124                NaN
#
# [125 rows x 6 columns]

# %%
variable_scatterplot('아파트 매매 실거래가격지수', '미래 아파트 매매 실거래가격지수')

# %%
variable_scatterplot('아파트 전세가격지수', '미래 아파트 매매 실거래가격지수')

# %%
variable_scatterplot('M1 유동성', '미래 아파트 매매 실거래가격지수')

# %%
variable_scatterplot('한국은행 기준금리', '미래 아파트 매매 실거래가격지수')

# %%
variable_scatterplot('경기선행지수', '미래 아파트 매매 실거래가격지수')

# %%
# 상관계수 히트맵
corr_matrix = data.corr()
sns.set(style='white')
f, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(corr_matrix, annot=True, cmap='Reds')
ax.set_xticklabels(['ASPI', 'ALPI', 'M1', 'IR', 'LEI', 'ASPI_1'], size=15, rotation=0)
ax.set_yticklabels(['ASPI', 'ALPI', 'M1', 'IR', 'LEI', 'ASPI_1'], size=15, rotation=0);

# %% [markdown]
# # 3. 모델링

# %% [markdown]
# * **다중선형회귀 및 ARIMA 모델은 R 코드 참조**

# %% [markdown]
# ## 3.1 RNN
# ### 하이퍼파라미터 종류
# * input_size: 설명변수의 개수(고정)
# * sequence_length: 종속변수를 예측할 때 사용할 과거 데이터의 개수 (RNN 함수의 하이퍼파라미터는 아님)
# * hidden size: hidden state(은닉 상태)에서의 변수 개수
# * num_layers: recurrent layers(순환 신경망)의 개수. 예를 들어 num_layers=2 이면 순환 신경망을 2개 쌓는다는 의미

# %%
input_size = 4 # 설명변수의 개수(고정)

# 하이퍼파라미터 탐색
sequence_lengths_ = [3, 6, 9]
hidden_sizes_ = [2, 3, 4, 5, 6, 7, 8]
num_layers_ = [1, 2, 3, 4, 5, 6, 7, 8]

params = []

for s in sequence_lengths_:
    for h in hidden_sizes_:
        for n in num_layers_:
            params.append([s, h, n])

# %%
# 데이터를 시퀀스 형태로 만들어주는 함수
def create_sequences(data, seq_length):
    sequences = []
    targets = []
    for i in range(len(data) - seq_length):
        seq = data[i:i+seq_length, :]  # 모든 열을 포함하는 입력 시퀀스로 사용
        target = data[i+seq_length, 0]  # 다음 행의 첫 번째 열을 타겟으로 사용
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# RNN 모델 정의
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.rnn(x, h0)
        out = self.fc(out[:, -1, :])
        return out

# %%
# 스케일링한 값을 원래 값으로 복원하기 위한 종속변수 최대, 최솟값 저장
M = max(data['아파트 매매 실거래가격지수'])
m = min(data['아파트 매매 실거래가격지수'])

# %%
# 다중선형회귀 모델에서의 다중공선성 존재로 인해 경기선행지수 변수 제거
data.drop(['경기선행지수', '미래 아파트 매매 실거래가격지수'], axis=1, inplace=True)

# %%
# 하이퍼파라미터 별 rmse, mae를 기록하기 위한 리스트 초기화
RMSE = []
MAE = []

# 최고 성능과 하이퍼파라미터 초기화
best_rmse = 10e9
best_params = [0, 0, 0]

for p in params:
    # 랜덤 시드 고정
    seed = 42
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    
    seq_length, hidden_size, num_layers = p[0], p[1], p[2]

    # 학습구간, 예측구간 데이터 분리(최근 17개월 데이터 예측)
    train = data.iloc[:-17, :] 
    test = data.iloc[-17 - seq_length:, :]

    # 변수 스케일링
    Scaler = MinMaxScaler()
    train_scaled = pd.DataFrame(Scaler.fit_transform(train), columns=train.columns)
    test_scaled = pd.DataFrame(Scaler.transform(test), columns=test.columns)

    # 입력 시퀀스 데이터, 출력 데이터 생성
    sequences, targets = create_sequences(train_scaled.values, seq_length)

    # 데이터를 PyTorch Tensor로 변환
    sequences = torch.FloatTensor(sequences)
    targets = torch.FloatTensor(targets).view(-1, 1)

    # RNN 모델 선언
    model = RNN(input_size, hidden_size, num_layers)

    # 손실 함수와 옵티마이저 선언
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=10e-3)

    # 과적합 방지를 위한 early stopping 함수(7번 epoch 연속으로 loss 미개선 시 조기 종료)
    early_stopping = EarlyStopping(patience = 7, verbose = False)

    # 모델 학습
    num_epochs = 1000
    for epoch in range(num_epochs):
        outputs = model(sequences)
        optimizer.zero_grad()
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        
        early_stopping(loss.item(), model) # 현재 과적합 상황 추적
    
        if early_stopping.early_stop: # 조건 만족 시 조기 종료
            print('종료 epoch:', epoch)
            break
    
    # test set에서의 시퀀스 생성
    test_sequences, _ = create_sequences(test_scaled.values, seq_length)
    test_sequences = torch.FloatTensor(test_sequences)
    
    # train, test 구간에서 예측값 구하기
    model.eval()
    with torch.no_grad():
        train_outputs = model(sequences)
        test_outputs = model(test_sequences)

    train_prediction = train_outputs * (M - m) + m # 스케일링 복원한 예측값(train)
    train_actual = data['아파트 매매 실거래가격지수'][seq_length:seq_length + len(train_prediction)] # 종속변수 실제 값(train)
    test_prediction = test_outputs * (M - m) + m # 스케일링 복원한 예측값(test)
    test_actual = data['아파트 매매 실거래가격지수'][-17:] # 종속변수 실제 값(test)
    
    # 학습 구간에서의 모델 성능
    train_rmse, train_mae = score(train_prediction, train_actual)
    test_rmse, test_mae = score(test_prediction, test_actual)
    rmse, mae = round(np.mean([train_rmse, test_rmse]), 4), round(np.mean([train_mae, test_mae]), 4) # 평균 성능
    RMSE.append(rmse)
    MAE.append(mae)
    print('sequence_length:', seq_length, 'hidden_size:', hidden_size, 'num_layers:', num_layers)
    print('RMSE:', rmse, 'MAE:', mae)
    print('-------------------------------------------------------------------------------------')
    
    if rmse < best_rmse:
        best_rmse = rmse
        best_params = [seq_length, hidden_size, num_layers]

print('최적의 하이퍼파라미터:', best_params)
print('최적 모델의 RMSE:', best_rmse)
# Out:
# sequence_length: 3 hidden_size: 2 num_layers: 1
# RMSE: 5.7698 MAE: 4.6239
# -------------------------------------------------------------------------------------
# 종료 epoch: 23
# sequence_length: 3 hidden_size: 2 num_layers: 2
# RMSE: 80.559 MAE: 71.1732
# -------------------------------------------------------------------------------------
# 종료 epoch: 44
# sequence_length: 3 hidden_size: 2 num_layers: 3
# RMSE: 28.0343 MAE: 17.9032
# -------------------------------------------------------------------------------------
# 종료 epoch: 41
# sequence_length: 3 hidden_size: 2 num_layers: 4
# RMSE: 22.8774 MAE: 20.7572
# -------------------------------------------------------------------------------------
# 종료 epoch: 22
# sequence_length: 3 hidden_size: 2 num_layers: 5
# RMSE: 67.2594 MAE: 60.9658
# -------------------------------------------------------------------------------------
# 종료 epoch: 17
# sequence_length: 3 hidden_size: 2 num_layers: 6
# RMSE: 57.0202 MAE: 52.0604
# -------------------------------------------------------------------------------------
# 종료 epoch: 29
# sequence_length: 3 hidden_size: 2 num_layers: 7
# RMSE: 59.4238 MAE: 54.4199
# -------------------------------------------------------------------------------------
# 종료 epoch: 16
# sequence_length: 3 hidden_size: 2 num_layers: 8
# RMSE: 55.89 MAE: 50.9355
# -------------------------------------------------------------------------------------
# 종료 epoch: 966
# sequence_length: 3 hidden_size: 3 num_layers: 1
# RMSE: 10.6634 MAE: 9.0165
# -------------------------------------------------------------------------------------
# 종료 epoch: 34
# sequence_length: 3 hidden_size: 3 num_layers: 2
# RMSE: 17.2865 MAE: 13.669
# -------------------------------------------------------------------------------------
# 종료 epoch: 29
# sequence_length: 3 hidden_size: 3 num_layers: 3
# RMSE: 14.025 MAE: 11.471
# -------------------------------------------------------------------------------------
# 종료 epoch: 19
# sequence_length: 3 hidden_size: 3 num_layers: 4
# RMSE: 55.79 MAE: 50.814
# -------------------------------------------------------------------------------------
# 종료 epoch: 26
# sequence_length: 3 hidden_size: 3 num_layers: 5
# RMSE: 18.2332 MAE: 13.9843
# -------------------------------------------------------------------------------------
# 종료 epoch: 99
# sequence_length: 3 hidden_size: 3 num_layers: 6
# RMSE: 15.5476 MAE: 12.7644
# -------------------------------------------------------------------------------------
# 종료 epoch: 46
# sequence_length: 3 hidden_size: 3 num_layers: 7
# RMSE: 57.7511 MAE: 52.7766
# -------------------------------------------------------------------------------------
# 종료 epoch: 11
# sequence_length: 3 hidden_size: 3 num_layers: 8
# RMSE: 61.9263 MAE: 56.6288
# -------------------------------------------------------------------------------------
# 종료 epoch: 16
# sequence_length: 3 hidden_size: 4 num_layers: 1
# RMSE: 11.4528 MAE: 10.2862
# -------------------------------------------------------------------------------------
# 종료 epoch: 40
# sequence_length: 3 hidden_size: 4 num_layers: 2
# RMSE: 8.6894 MAE: 7.5488
# -------------------------------------------------------------------------------------
# 종료 epoch: 13
# sequence_length: 3 hidden_size: 4 num_layers: 3
# RMSE: 56.0192 MAE: 51.117
# -------------------------------------------------------------------------------------
# 종료 epoch: 13
# sequence_length: 3 hidden_size: 4 num_layers: 4
# RMSE: 67.815 MAE: 61.315
# -------------------------------------------------------------------------------------
# 종료 epoch: 15
# sequence_length: 3 hidden_size: 4 num_layers: 5
# RMSE: 54.645 MAE: 49.6994
# -------------------------------------------------------------------------------------
# 종료 epoch: 38
# sequence_length: 3 hidden_size: 4 num_layers: 6
# RMSE: 20.3551 MAE: 16.3747
# -------------------------------------------------------------------------------------
# 종료 epoch: 17
# sequence_length: 3 hidden_size: 4 num_layers: 7
# RMSE: 54.7996 MAE: 49.834
# -------------------------------------------------------------------------------------
# 종료 epoch: 18
# sequence_length: 3 hidden_size: 4 num_layers: 8
# RMSE: 63.3476 MAE: 57.808
# -------------------------------------------------------------------------------------
# 종료 epoch: 49
# sequence_length: 3 hidden_size: 5 num_layers: 1
# RMSE: 19.8798 MAE: 17.7026
# -------------------------------------------------------------------------------------
# 종료 epoch: 20
# sequence_length: 3 hidden_size: 5 num_layers: 2
# RMSE: 9.1854 MAE: 6.892
# -------------------------------------------------------------------------------------
# 종료 epoch: 24
# sequence_length: 3 hidden_size: 5 num_layers: 3
# RMSE: 11.4761 MAE: 9.1895
# -------------------------------------------------------------------------------------
# 종료 epoch: 35
# sequence_length: 3 hidden_size: 5 num_layers: 4
# RMSE: 14.671 MAE: 12.133
# -------------------------------------------------------------------------------------
# 종료 epoch: 27
# sequence_length: 3 hidden_size: 5 num_layers: 5
# RMSE: 13.0633 MAE: 11.462
# -------------------------------------------------------------------------------------
# 종료 epoch: 12
# sequence_length: 3 hidden_size: 5 num_layers: 6
# RMSE: 56.5368 MAE: 51.6221
# -------------------------------------------------------------------------------------
# 종료 epoch: 11
# sequence_length: 3 hidden_size: 5 num_layers: 7
# RMSE: 60.6352 MAE: 55.5238
# -------------------------------------------------------------------------------------
# 종료 epoch: 94
# sequence_length: 3 hidden_size: 5 num_layers: 8
# RMSE: 8.5782 MAE: 6.328
# -------------------------------------------------------------------------------------
# 종료 epoch: 589
# sequence_length: 3 hidden_size: 6 num_layers: 1
# RMSE: 8.5218 MAE: 7.169
# -------------------------------------------------------------------------------------
# 종료 epoch: 215
# sequence_length: 3 hidden_size: 6 num_layers: 2
# RMSE: 10.2902 MAE: 8.332
# -------------------------------------------------------------------------------------
# 종료 epoch: 67
# sequence_length: 3 hidden_size: 6 num_layers: 3
# RMSE: 16.1694 MAE: 13.261
# -------------------------------------------------------------------------------------
# 종료 epoch: 25
# sequence_length: 3 hidden_size: 6 num_layers: 4
# RMSE: 13.1252 MAE: 11.5597
# -------------------------------------------------------------------------------------
# 종료 epoch: 28
# sequence_length: 3 hidden_size: 6 num_layers: 5
# RMSE: 15.7189 MAE: 12.2228
# -------------------------------------------------------------------------------------
# 종료 epoch: 51
# sequence_length: 3 hidden_size: 6 num_layers: 6
# RMSE: 24.6658 MAE: 17.7262
# -------------------------------------------------------------------------------------
# 종료 epoch: 385
# sequence_length: 3 hidden_size: 6 num_layers: 7
# RMSE: 15.276 MAE: 13.2398
# -------------------------------------------------------------------------------------
# 종료 epoch: 38
# sequence_length: 3 hidden_size: 6 num_layers: 8
# RMSE: 21.787 MAE: 17.3109
# -------------------------------------------------------------------------------------
# 종료 epoch: 30
# sequence_length: 3 hidden_size: 7 num_layers: 1
# RMSE: 12.6102 MAE: 9.6896
# -------------------------------------------------------------------------------------
# 종료 epoch: 31
# sequence_length: 3 hidden_size: 7 num_layers: 2
# RMSE: 8.8018 MAE: 7.4901
# -------------------------------------------------------------------------------------
# 종료 epoch: 22
# sequence_length: 3 hidden_size: 7 num_layers: 3
# RMSE: 12.8751 MAE: 9.8951
# -------------------------------------------------------------------------------------
# 종료 epoch: 11
# sequence_length: 3 hidden_size: 7 num_layers: 4
# RMSE: 60.3276 MAE: 55.2238
# -------------------------------------------------------------------------------------
# 종료 epoch: 25
# sequence_length: 3 hidden_size: 7 num_layers: 5
# RMSE: 16.4426 MAE: 10.6389
# -------------------------------------------------------------------------------------
# 종료 epoch: 10
# sequence_length: 3 hidden_size: 7 num_layers: 6
# RMSE: 64.1554 MAE: 58.5175
# -------------------------------------------------------------------------------------
# 종료 epoch: 392
# sequence_length: 3 hidden_size: 7 num_layers: 7
# RMSE: 16.7677 MAE: 14.7288
# -------------------------------------------------------------------------------------
# 종료 epoch: 239
# sequence_length: 3 hidden_size: 7 num_layers: 8
# RMSE: 14.664 MAE: 11.9588
# -------------------------------------------------------------------------------------
# 종료 epoch: 16
# sequence_length: 3 hidden_size: 8 num_layers: 1
# RMSE: 13.0922 MAE: 10.44
# -------------------------------------------------------------------------------------
# 종료 epoch: 19
# sequence_length: 3 hidden_size: 8 num_layers: 2
# RMSE: 12.2451 MAE: 9.6667
# -------------------------------------------------------------------------------------
# 종료 epoch: 30
# sequence_length: 3 hidden_size: 8 num_layers: 3
# RMSE: 11.5647 MAE: 10.078
# -------------------------------------------------------------------------------------
# 종료 epoch: 34
# sequence_length: 3 hidden_size: 8 num_layers: 4
# RMSE: 14.4209 MAE: 10.4788
# -------------------------------------------------------------------------------------
# 종료 epoch: 36
# sequence_length: 3 hidden_size: 8 num_layers: 5
# RMSE: 20.9752 MAE: 16.4393
# -------------------------------------------------------------------------------------
# 종료 epoch: 43
# sequence_length: 3 hidden_size: 8 num_layers: 6
# RMSE: 12.64 MAE: 10.5931
# -------------------------------------------------------------------------------------
# 종료 epoch: 18
# sequence_length: 3 hidden_size: 8 num_layers: 7
# RMSE: 57.4523 MAE: 52.5161
# -------------------------------------------------------------------------------------
# 종료 epoch: 33
# sequence_length: 3 hidden_size: 8 num_layers: 8
# RMSE: 20.3128 MAE: 16.6855
# -------------------------------------------------------------------------------------
# sequence_length: 6 hidden_size: 2 num_layers: 1
# RMSE: 7.4443 MAE: 6.2571
# -------------------------------------------------------------------------------------
# 종료 epoch: 23
# sequence_length: 6 hidden_size: 2 num_layers: 2
# RMSE: 79.0626 MAE: 69.8147
# -------------------------------------------------------------------------------------
# 종료 epoch: 43
# sequence_length: 6 hidden_size: 2 num_layers: 3
# RMSE: 24.8673 MAE: 16.5782
# -------------------------------------------------------------------------------------
# 종료 epoch: 39
# sequence_length: 6 hidden_size: 2 num_layers: 4
# RMSE: 16.7246 MAE: 13.91
# -------------------------------------------------------------------------------------
# 종료 epoch: 22
# sequence_length: 6 hidden_size: 2 num_layers: 5
# RMSE: 66.4118 MAE: 60.1832
# -------------------------------------------------------------------------------------
# 종료 epoch: 17
# sequence_length: 6 hidden_size: 2 num_layers: 6
# RMSE: 56.3146 MAE: 51.2958
# -------------------------------------------------------------------------------------
# 종료 epoch: 30
# sequence_length: 6 hidden_size: 2 num_layers: 7
# RMSE: 58.6144 MAE: 53.548
# -------------------------------------------------------------------------------------
# 종료 epoch: 16
# sequence_length: 6 hidden_size: 2 num_layers: 8
# RMSE: 55.0953 MAE: 50.0902
# -------------------------------------------------------------------------------------
# 종료 epoch: 33
# sequence_length: 6 hidden_size: 3 num_layers: 1
# RMSE: 43.2764 MAE: 34.4266
# -------------------------------------------------------------------------------------
# 종료 epoch: 70
# sequence_length: 6 hidden_size: 3 num_layers: 2
# RMSE: 11.0352 MAE: 8.8836
# -------------------------------------------------------------------------------------
# 종료 epoch: 31
# sequence_length: 6 hidden_size: 3 num_layers: 3
# RMSE: 13.7776 MAE: 11.7354
# -------------------------------------------------------------------------------------
# 종료 epoch: 19
# sequence_length: 6 hidden_size: 3 num_layers: 4
# RMSE: 55.1049 MAE: 50.091
# -------------------------------------------------------------------------------------
# 종료 epoch: 331
# sequence_length: 6 hidden_size: 3 num_layers: 5
# RMSE: 13.7855 MAE: 12.5836
# -------------------------------------------------------------------------------------
# 종료 epoch: 405
# sequence_length: 6 hidden_size: 3 num_layers: 6
# RMSE: 4.7 MAE: 3.9662
# -------------------------------------------------------------------------------------
# 종료 epoch: 44
# sequence_length: 6 hidden_size: 3 num_layers: 7
# RMSE: 57.2204 MAE: 52.1753
# -------------------------------------------------------------------------------------
# 종료 epoch: 10
# sequence_length: 6 hidden_size: 3 num_layers: 8
# RMSE: 60.1978 MAE: 55.0266
# -------------------------------------------------------------------------------------
# 종료 epoch: 16
# sequence_length: 6 hidden_size: 4 num_layers: 1
# RMSE: 10.2282 MAE: 8.563
# -------------------------------------------------------------------------------------
# 종료 epoch: 48
# sequence_length: 6 hidden_size: 4 num_layers: 2
# RMSE: 8.9684 MAE: 7.2472
# -------------------------------------------------------------------------------------
# 종료 epoch: 13
# sequence_length: 6 hidden_size: 4 num_layers: 3
# RMSE: 55.4606 MAE: 50.5334
# -------------------------------------------------------------------------------------
# 종료 epoch: 12
# sequence_length: 6 hidden_size: 4 num_layers: 4
# RMSE: 66.8522 MAE: 60.389
# -------------------------------------------------------------------------------------
# 종료 epoch: 15
# sequence_length: 6 hidden_size: 4 num_layers: 5
# RMSE: 56.449 MAE: 51.3908
# -------------------------------------------------------------------------------------
# 종료 epoch: 9
# sequence_length: 6 hidden_size: 4 num_layers: 6
# RMSE: 63.2379 MAE: 57.5778
# -------------------------------------------------------------------------------------
# 종료 epoch: 16
# sequence_length: 6 hidden_size: 4 num_layers: 7
# RMSE: 54.1465 MAE: 49.2224
# -------------------------------------------------------------------------------------
# 종료 epoch: 48
# sequence_length: 6 hidden_size: 4 num_layers: 8
# RMSE: 10.4952 MAE: 8.4248
# -------------------------------------------------------------------------------------
# 종료 epoch: 50
# sequence_length: 6 hidden_size: 5 num_layers: 1
# RMSE: 18.5044 MAE: 16.362
# -------------------------------------------------------------------------------------
# 종료 epoch: 18
# sequence_length: 6 hidden_size: 5 num_layers: 2
# RMSE: 10.669 MAE: 8.5652
# -------------------------------------------------------------------------------------
# 종료 epoch: 18
# sequence_length: 6 hidden_size: 5 num_layers: 3
# RMSE: 14.3124 MAE: 12.059
# -------------------------------------------------------------------------------------
# 종료 epoch: 19
# sequence_length: 6 hidden_size: 5 num_layers: 4
# RMSE: 62.1412 MAE: 56.695
# -------------------------------------------------------------------------------------
# 종료 epoch: 24
# sequence_length: 6 hidden_size: 5 num_layers: 5
# RMSE: 15.8257 MAE: 13.8368
# -------------------------------------------------------------------------------------
# 종료 epoch: 13
# sequence_length: 6 hidden_size: 5 num_layers: 6
# RMSE: 55.6088 MAE: 50.9348
# -------------------------------------------------------------------------------------
# 종료 epoch: 11
# sequence_length: 6 hidden_size: 5 num_layers: 7
# RMSE: 60.9287 MAE: 55.6732
# -------------------------------------------------------------------------------------
# 종료 epoch: 48
# sequence_length: 6 hidden_size: 5 num_layers: 8
# RMSE: 19.7758 MAE: 16.5306
# -------------------------------------------------------------------------------------
# 종료 epoch: 73
# sequence_length: 6 hidden_size: 6 num_layers: 1
# RMSE: 10.9299 MAE: 9.301
# -------------------------------------------------------------------------------------
# 종료 epoch: 66
# sequence_length: 6 hidden_size: 6 num_layers: 2
# RMSE: 10.3135 MAE: 8.2401
# -------------------------------------------------------------------------------------
# 종료 epoch: 36
# sequence_length: 6 hidden_size: 6 num_layers: 3
# RMSE: 12.5357 MAE: 10.3683
# -------------------------------------------------------------------------------------
# 종료 epoch: 25
# sequence_length: 6 hidden_size: 6 num_layers: 4
# RMSE: 8.8258 MAE: 7.3734
# -------------------------------------------------------------------------------------
# 종료 epoch: 28
# sequence_length: 6 hidden_size: 6 num_layers: 5
# RMSE: 18.1167 MAE: 15.1849
# -------------------------------------------------------------------------------------
# 종료 epoch: 12
# sequence_length: 6 hidden_size: 6 num_layers: 6
# RMSE: 64.6993 MAE: 58.8162
# -------------------------------------------------------------------------------------
# 종료 epoch: 38
# sequence_length: 6 hidden_size: 6 num_layers: 7
# RMSE: 22.5725 MAE: 19.6656
# -------------------------------------------------------------------------------------
# 종료 epoch: 40
# sequence_length: 6 hidden_size: 6 num_layers: 8
# RMSE: 13.3258 MAE: 10.5232
# -------------------------------------------------------------------------------------
# 종료 epoch: 36
# sequence_length: 6 hidden_size: 7 num_layers: 1
# RMSE: 16.7171 MAE: 13.0645
# -------------------------------------------------------------------------------------
# 종료 epoch: 30
# sequence_length: 6 hidden_size: 7 num_layers: 2
# RMSE: 12.8009 MAE: 10.0472
# -------------------------------------------------------------------------------------
# 종료 epoch: 21
# sequence_length: 6 hidden_size: 7 num_layers: 3
# RMSE: 15.2462 MAE: 11.5299
# -------------------------------------------------------------------------------------
# 종료 epoch: 12
# sequence_length: 6 hidden_size: 7 num_layers: 4
# RMSE: 59.1452 MAE: 54.1076
# -------------------------------------------------------------------------------------
# 종료 epoch: 361
# sequence_length: 6 hidden_size: 7 num_layers: 5
# RMSE: 8.6832 MAE: 7.4949
# -------------------------------------------------------------------------------------
# 종료 epoch: 10
# sequence_length: 6 hidden_size: 7 num_layers: 6
# RMSE: 60.5765 MAE: 55.3643
# -------------------------------------------------------------------------------------
# 종료 epoch: 40
# sequence_length: 6 hidden_size: 7 num_layers: 7
# RMSE: 16.206 MAE: 12.7598
# -------------------------------------------------------------------------------------
# 종료 epoch: 54
# sequence_length: 6 hidden_size: 7 num_layers: 8
# RMSE: 14.195 MAE: 10.3382
# -------------------------------------------------------------------------------------
# 종료 epoch: 17
# sequence_length: 6 hidden_size: 8 num_layers: 1
# RMSE: 11.9917 MAE: 9.1077
# -------------------------------------------------------------------------------------
# 종료 epoch: 78
# sequence_length: 6 hidden_size: 8 num_layers: 2
# RMSE: 10.5003 MAE: 8.875
# -------------------------------------------------------------------------------------
# 종료 epoch: 27
# sequence_length: 6 hidden_size: 8 num_layers: 3
# RMSE: 12.7566 MAE: 10.2164
# -------------------------------------------------------------------------------------
# 종료 epoch: 34
# sequence_length: 6 hidden_size: 8 num_layers: 4
# RMSE: 17.9089 MAE: 15.0354
# -------------------------------------------------------------------------------------
# 종료 epoch: 30
# sequence_length: 6 hidden_size: 8 num_layers: 5
# RMSE: 18.9242 MAE: 16.0774
# -------------------------------------------------------------------------------------
# 종료 epoch: 52
# sequence_length: 6 hidden_size: 8 num_layers: 6
# RMSE: 15.5534 MAE: 12.1027
# -------------------------------------------------------------------------------------
# 종료 epoch: 25
# sequence_length: 6 hidden_size: 8 num_layers: 7
# RMSE: 58.5616 MAE: 53.4998
# -------------------------------------------------------------------------------------
# 종료 epoch: 24
# sequence_length: 6 hidden_size: 8 num_layers: 8
# RMSE: 22.657 MAE: 15.9154
# -------------------------------------------------------------------------------------
# sequence_length: 9 hidden_size: 2 num_layers: 1
# RMSE: 7.9045 MAE: 6.7406
# -------------------------------------------------------------------------------------
# 종료 epoch: 22
# sequence_length: 9 hidden_size: 2 num_layers: 2
# RMSE: 78.8446 MAE: 69.6565
# -------------------------------------------------------------------------------------
# 종료 epoch: 42
# sequence_length: 9 hidden_size: 2 num_layers: 3
# RMSE: 23.0732 MAE: 15.8992
# -------------------------------------------------------------------------------------
# 종료 epoch: 38
# sequence_length: 9 hidden_size: 2 num_layers: 4
# RMSE: 21.2922 MAE: 17.9584
# -------------------------------------------------------------------------------------
# 종료 epoch: 21
# sequence_length: 9 hidden_size: 2 num_layers: 5
# RMSE: 65.5198 MAE: 59.3434
# -------------------------------------------------------------------------------------
# 종료 epoch: 18
# sequence_length: 9 hidden_size: 2 num_layers: 6
# RMSE: 55.5231 MAE: 50.4583
# -------------------------------------------------------------------------------------
# 종료 epoch: 31
# sequence_length: 9 hidden_size: 2 num_layers: 7
# RMSE: 58.0146 MAE: 52.8714
# -------------------------------------------------------------------------------------
# 종료 epoch: 17
# sequence_length: 9 hidden_size: 2 num_layers: 8
# RMSE: 54.3396 MAE: 49.2995
# -------------------------------------------------------------------------------------
# 종료 epoch: 33
# sequence_length: 9 hidden_size: 3 num_layers: 1
# RMSE: 42.5374 MAE: 33.1602
# -------------------------------------------------------------------------------------
# sequence_length: 9 hidden_size: 3 num_layers: 2
# RMSE: 7.4666 MAE: 6.3362
# -------------------------------------------------------------------------------------
# 종료 epoch: 31
# sequence_length: 9 hidden_size: 3 num_layers: 3
# RMSE: 13.0271 MAE: 10.8161
# -------------------------------------------------------------------------------------
# 종료 epoch: 19
# sequence_length: 9 hidden_size: 3 num_layers: 4
# RMSE: 53.6196 MAE: 48.5683
# -------------------------------------------------------------------------------------
# 종료 epoch: 345
# sequence_length: 9 hidden_size: 3 num_layers: 5
# RMSE: 13.3587 MAE: 12.2374
# -------------------------------------------------------------------------------------
# 종료 epoch: 16
# sequence_length: 9 hidden_size: 3 num_layers: 6
# RMSE: 57.5382 MAE: 52.3984
# -------------------------------------------------------------------------------------
# 종료 epoch: 44
# sequence_length: 9 hidden_size: 3 num_layers: 7
# RMSE: 56.3818 MAE: 51.2912
# -------------------------------------------------------------------------------------
# 종료 epoch: 11
# sequence_length: 9 hidden_size: 3 num_layers: 8
# RMSE: 59.9299 MAE: 54.6738
# -------------------------------------------------------------------------------------
# 종료 epoch: 17
# sequence_length: 9 hidden_size: 4 num_layers: 1
# RMSE: 9.6943 MAE: 7.7928
# -------------------------------------------------------------------------------------
# 종료 epoch: 48
# sequence_length: 9 hidden_size: 4 num_layers: 2
# RMSE: 9.1405 MAE: 7.3843
# -------------------------------------------------------------------------------------
# 종료 epoch: 13
# sequence_length: 9 hidden_size: 4 num_layers: 3
# RMSE: 54.3418 MAE: 49.369
# -------------------------------------------------------------------------------------
# 종료 epoch: 12
# sequence_length: 9 hidden_size: 4 num_layers: 4
# RMSE: 67.4932 MAE: 60.7274
# -------------------------------------------------------------------------------------
# 종료 epoch: 16
# sequence_length: 9 hidden_size: 4 num_layers: 5
# RMSE: 53.1648 MAE: 48.1208
# -------------------------------------------------------------------------------------
# 종료 epoch: 97
# sequence_length: 9 hidden_size: 4 num_layers: 6
# RMSE: 13.6484 MAE: 11.1112
# -------------------------------------------------------------------------------------
# 종료 epoch: 18
# sequence_length: 9 hidden_size: 4 num_layers: 7
# RMSE: 53.9113 MAE: 48.8768
# -------------------------------------------------------------------------------------
# 종료 epoch: 37
# sequence_length: 9 hidden_size: 4 num_layers: 8
# RMSE: 24.0526 MAE: 20.3782
# -------------------------------------------------------------------------------------
# sequence_length: 9 hidden_size: 5 num_layers: 1
# RMSE: 7.5376 MAE: 6.3592
# -------------------------------------------------------------------------------------
# 종료 epoch: 18
# sequence_length: 9 hidden_size: 5 num_layers: 2
# RMSE: 10.6146 MAE: 8.5681
# -------------------------------------------------------------------------------------
# 종료 epoch: 17
# sequence_length: 9 hidden_size: 5 num_layers: 3
# RMSE: 14.4619 MAE: 12.2473
# -------------------------------------------------------------------------------------
# 종료 epoch: 18
# sequence_length: 9 hidden_size: 5 num_layers: 4
# RMSE: 61.2053 MAE: 55.7719
# -------------------------------------------------------------------------------------
# 종료 epoch: 24
# sequence_length: 9 hidden_size: 5 num_layers: 5
# RMSE: 15.139 MAE: 13.3298
# -------------------------------------------------------------------------------------
# 종료 epoch: 13
# sequence_length: 9 hidden_size: 5 num_layers: 6
# RMSE: 55.2354 MAE: 50.2154
# -------------------------------------------------------------------------------------
# 종료 epoch: 11
# sequence_length: 9 hidden_size: 5 num_layers: 7
# RMSE: 59.1316 MAE: 53.9554
# -------------------------------------------------------------------------------------
# 종료 epoch: 48
# sequence_length: 9 hidden_size: 5 num_layers: 8
# RMSE: 22.237 MAE: 19.0422
# -------------------------------------------------------------------------------------
# 종료 epoch: 80
# sequence_length: 9 hidden_size: 6 num_layers: 1
# RMSE: 10.8042 MAE: 9.7332
# -------------------------------------------------------------------------------------
# 종료 epoch: 63
# sequence_length: 9 hidden_size: 6 num_layers: 2
# RMSE: 9.3078 MAE: 7.4206
# -------------------------------------------------------------------------------------
# 종료 epoch: 13
# sequence_length: 9 hidden_size: 6 num_layers: 3
# RMSE: 58.9368 MAE: 53.6857
# -------------------------------------------------------------------------------------
# 종료 epoch: 25
# sequence_length: 9 hidden_size: 6 num_layers: 4
# RMSE: 9.4946 MAE: 7.809
# -------------------------------------------------------------------------------------
# 종료 epoch: 31
# sequence_length: 9 hidden_size: 6 num_layers: 5
# RMSE: 20.7364 MAE: 16.7283
# -------------------------------------------------------------------------------------
# 종료 epoch: 253
# sequence_length: 9 hidden_size: 6 num_layers: 6
# RMSE: 13.4914 MAE: 11.0828
# -------------------------------------------------------------------------------------
# 종료 epoch: 25
# sequence_length: 9 hidden_size: 6 num_layers: 7
# RMSE: 18.7162 MAE: 14.4159
# -------------------------------------------------------------------------------------
# 종료 epoch: 152
# sequence_length: 9 hidden_size: 6 num_layers: 8
# RMSE: 24.3592 MAE: 20.5682
# -------------------------------------------------------------------------------------
# 종료 epoch: 38
# sequence_length: 9 hidden_size: 7 num_layers: 1
# RMSE: 16.8501 MAE: 12.8555
# -------------------------------------------------------------------------------------
# 종료 epoch: 20
# sequence_length: 9 hidden_size: 7 num_layers: 2
# RMSE: 11.574 MAE: 8.4401
# -------------------------------------------------------------------------------------
# 종료 epoch: 13
# sequence_length: 9 hidden_size: 7 num_layers: 3
# RMSE: 16.6302 MAE: 14.105
# -------------------------------------------------------------------------------------
# 종료 epoch: 12
# sequence_length: 9 hidden_size: 7 num_layers: 4
# RMSE: 59.409 MAE: 54.2462
# -------------------------------------------------------------------------------------
# 종료 epoch: 27
# sequence_length: 9 hidden_size: 7 num_layers: 5
# RMSE: 24.2492 MAE: 18.8054
# -------------------------------------------------------------------------------------
# 종료 epoch: 18
# sequence_length: 9 hidden_size: 7 num_layers: 6
# RMSE: 63.476 MAE: 57.6689
# -------------------------------------------------------------------------------------
# 종료 epoch: 370
# sequence_length: 9 hidden_size: 7 num_layers: 7
# RMSE: 15.8926 MAE: 13.9254
# -------------------------------------------------------------------------------------
# 종료 epoch: 53
# sequence_length: 9 hidden_size: 7 num_layers: 8
# RMSE: 17.5852 MAE: 13.5246
# -------------------------------------------------------------------------------------
# 종료 epoch: 17
# sequence_length: 9 hidden_size: 8 num_layers: 1
# RMSE: 12.5413 MAE: 9.7326
# -------------------------------------------------------------------------------------
# sequence_length: 9 hidden_size: 8 num_layers: 2
# RMSE: 7.486 MAE: 6.4399
# -------------------------------------------------------------------------------------
# 종료 epoch: 27
# sequence_length: 9 hidden_size: 8 num_layers: 3
# RMSE: 13.8193 MAE: 11.4002
# -------------------------------------------------------------------------------------
# 종료 epoch: 43
# sequence_length: 9 hidden_size: 8 num_layers: 4
# RMSE: 19.5445 MAE: 16.464
# -------------------------------------------------------------------------------------
# 종료 epoch: 30
# sequence_length: 9 hidden_size: 8 num_layers: 5
# RMSE: 16.7835 MAE: 14.3916
# -------------------------------------------------------------------------------------
# 종료 epoch: 195
# sequence_length: 9 hidden_size: 8 num_layers: 6
# RMSE: 15.5784 MAE: 13.6022
# -------------------------------------------------------------------------------------
# 종료 epoch: 19
# sequence_length: 9 hidden_size: 8 num_layers: 7
# RMSE: 61.6613 MAE: 56.168
# -------------------------------------------------------------------------------------
# 종료 epoch: 103
# sequence_length: 9 hidden_size: 8 num_layers: 8
# RMSE: 16.816 MAE: 14.0348
# -------------------------------------------------------------------------------------
# 최적의 하이퍼파라미터: [6, 3, 6]
# 최적 모델의 RMSE: 4.7

# %%
# 하이퍼파라미터 별 모델의 성능을 저장한 데이터프레임
score_df = pd.DataFrame(params, columns=['sequence_length', 'hidden_size', 'num_layers'])
score_df['RMSE'] = RMSE
score_df['MAE'] = MAE
score_df
# Out:
#      sequence_length  hidden_size  num_layers     RMSE      MAE
# 0                  3            2           1   5.7698   4.6239
# 1                  3            2           2  80.5590  71.1732
# 2                  3            2           3  28.0343  17.9032
# 3                  3            2           4  22.8774  20.7572
# 4                  3            2           5  67.2594  60.9658
# ..               ...          ...         ...      ...      ...
# 163                9            8           4  19.5445  16.4640
# 164                9            8           5  16.7835  14.3916
# 165                9            8           6  15.5784  13.6022
# 166                9            8           7  61.6613  56.1680
# 167                9            8           8  16.8160  14.0348
#
# [168 rows x 5 columns]

# %%
# 최적 모델의 예측값
seq_length, hidden_size, num_layers = best_params[0], best_params[1], best_params[2]

# 랜덤 시드 고정
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(seed)

# 학습구간, 예측구간 데이터 분리(최근 17개월 데이터 예측)
train = data.iloc[:-17, :] 
test = data.iloc[-17 - seq_length:, :]

# 변수 스케일링
Scaler = MinMaxScaler()
train_scaled = pd.DataFrame(Scaler.fit_transform(train), columns=train.columns)
test_scaled = pd.DataFrame(Scaler.transform(test), columns=test.columns)

# 입력 시퀀스 데이터, 출력 데이터 생성
sequences, targets = create_sequences(train_scaled.values, seq_length)

# 데이터를 PyTorch Tensor로 변환
sequences = torch.FloatTensor(sequences)
targets = torch.FloatTensor(targets).view(-1, 1)

# RNN 모델 선언
model = RNN(input_size, hidden_size, num_layers)

# 손실 함수와 옵티마이저 선언
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=10e-3)

# 과적합 방지를 위한 early stopping 함수(7번 epoch 연속으로 loss 미개선 시 조기 종료)
early_stopping = EarlyStopping(patience = 7, verbose = False)

# 모델 학습
num_epochs = 1000
for epoch in range(num_epochs):
    outputs = model(sequences)
    optimizer.zero_grad()
    loss = criterion(outputs, targets)
    loss.backward()
    optimizer.step()

    early_stopping(loss.item(), model) # 현재 과적합 상황 추적

    if early_stopping.early_stop: # 조건 만족 시 조기 종료
        print('종료 epoch:', epoch)
        break

# test set에서의 시퀀스 생성
test_sequences, _ = create_sequences(test_scaled.values, seq_length)
test_sequences = torch.FloatTensor(test_sequences)

# train, test 구간에서 예측값 구하기
model.eval()
with torch.no_grad():
    train_outputs = model(sequences)
    test_outputs = model(test_sequences)

train_prediction = train_outputs * (M - m) + m # 스케일링 복원한 예측값(train)
test_prediction = test_outputs * (M - m) + m # 스케일링 복원한 예측값(test)

train_prediction = train_prediction.tolist()
test_prediction = test_prediction.tolist()

# 최종 예측 결과(train, test) 저장
rnn_prediction = train_prediction + test_prediction
# Out:
# 종료 epoch: 405

# %% [markdown]
# # 4. 결과 시각화

# %% [markdown]
# ## 4.1 다중선형회귀 및 ARIMA 모델 결과 시각화

# %%
# 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
residuals = pd.read_csv('res.csv')
residuals = residuals['x'].tolist()

time_range = pd.date_range(start='2013-01-01', end='2023-05-01', freq='M')
plt.figure(figsize=(12, 6))

plt.plot(time_range, residuals, label='잔차', color='black')
plt.xlabel('Time', fontsize=18)
plt.ylabel('잔차', fontsize=18)
plt.title('회귀모형 잔차', fontsize=20)
plt.grid(True)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.tight_layout()
plt.show()

# %%
# ACF
plt.figure(figsize=(12, 6))
plot_acf(np.array(residuals), lags=24)
plt.xlabel('Lags', fontsize=18)
plt.ylabel('ACF', fontsize=18)
plt.title('잔차 ACF', fontsize=20)
plt.grid(True)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.show()

# %%
# PACF
plt.figure(figsize=(12, 6))
plot_pacf(np.array(residuals), lags=24, method='ywm')
plt.xlabel('Lags', fontsize=18)
plt.ylabel('PACF', fontsize=18)
plt.title('잔차 PACF', fontsize=20)
plt.grid(True)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.show()

# %%
# 회귀 및 arima 모델의 fitting value 및 신뢰구간
conf_int = pd.read_csv('conf_interval_arima.csv')
display(conf_int[['lwr', 'fit', 'upr']])

# 95% 신뢰구간과 fittied_value 저장
lower = np.array(conf_int['lwr'])
upper = np.array(conf_int['upr'])
fitted_values = np.array(conf_int['fit'])
# Out:
#            lwr         fit         upr
# 0   249.491029  253.453065  257.415100
# 1   246.566430  250.839888  255.113347
# 2   241.554974  245.859024  250.163073
# 3   250.519489  254.977546  259.435604
# 4   248.036021  252.841429  257.646837
# 5   239.431246  244.608730  249.786214
# 6   245.726306  251.005799  256.285293
# 7   222.728703  229.316573  235.904444
# 8   220.715146  227.592723  234.470300
# 9   216.686265  223.508308  230.330351
# 10  200.336931  207.868827  215.400723
# 11  185.339627  193.045500  200.751372
# 12  184.279512  191.617901  198.956290
# 13  189.857012  197.444018  205.031023
# 14  194.474247  202.002198  209.530149
# 15  197.171060  204.685960  212.200861
# 16  201.303572  208.892432  216.481292

# %%
predict = pd.read_csv('predict.csv')
lr_prediction = predict['x'].values

# %%
# 전체 구간 예측 결과 시각화
result_plot('2013-02-01', '2023-06-01', '2022-01-01', data['아파트 매매 실거래가격지수'][1:], lr_prediction, "다중선형회귀 및 ARIMA")

# %%
time_range = pd.date_range(start='2013-02-01', end='2023-06-01', freq='M')
    
# 그래프 크기 설정
plt.figure(figsize=(12, 6))

# 그래프 그리기
plt.plot(time_range[-17:], data['아파트 매매 실거래가격지수'][-17:], label='실제 값', color='black')
plt.plot(time_range[-17:], fitted_values, label='예측 값', color='red')
plt.fill_between(time_range[-17:], lower, upper, color='pink')

# 축 제목, 크기 설정
plt.xlabel('Time', fontsize=18)
plt.ylabel('소비자물가지수', fontsize=18)
plt.title('다중선형회귀 및 ARIMA 모형', fontsize=20)
plt.legend(fontsize=18)
plt.grid(True)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.tight_layout()

# 그래프 보이기
plt.show()

# %% [markdown]
# ## 4.2 RNN 모델 예측 결과 출력 및 시각화

# %%
rmse, mae = score(data['아파트 매매 실거래가격지수'][-17:], rnn_prediction[-17:])
print('RNN 모델 test set에서의 RMSE:', rmse)
print('RNN 모델 test set에서의 MAE:', mae)
# Out:
# RNN 모델 test set에서의 RMSE: 7.6833
# RNN 모델 test set에서의 MAE: 6.4589

# %%
# 전체 구간
start = datetime.strptime('2013-01-01', '%Y-%m-%d') + timedelta(days=30.44 * (seq_length - 1))
start = start.strftime('%Y-%m-%d')
result_plot(start, '2023-05-01', '2022-01-01', data['아파트 매매 실거래가격지수'][seq_length:], rnn_prediction, 'RNN')

# %%
# 예측 구간
result_plot('2021-12-01', '2023-05-01', '2022-01-01', data['아파트 매매 실거래가격지수'][-17:], rnn_prediction[-17:], 'RNN')
